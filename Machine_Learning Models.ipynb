# %% [markdown]
# Maching Learning Models -:
#
# 1. Data Creating--> Data cleaning and preprocessing--> Select Ml Model based on target data-->
# 2. Model Training--> Model Prediction--> Evaluate the model
#
# # Types of ML models-:
#
# 1. Supervised ML Model--> In this we will provide values with label
#
# 2. Unsupervised ML Model--> In this, we will provide only values not column name.
#
#
# # Supervised ML model
#
# # Target Data
# 1. Numerical---> LinearRegression, DecisionTreeRegression, RandomForestRegression
#
# 2. Categorical---> LogisticRegression, Decision

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/insurance - insurance.csv')

# %%
df.head(3)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523
# 2   28    male  33.00         3     no  southeast   4449.4620

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
df['sex']=lb.fit_transform(df['sex'])
df['smoker']=lb.fit_transform(df['smoker'])
df['region']=lb.fit_transform(df['region'])

# %%
df.head(3)
# Out:
#    age  sex    bmi  children  smoker  region     charges
# 0   19    0  27.90         0       1       3  16884.9240
# 1   18    1  33.77         1       0       2   1725.5523
# 2   28    1  33.00         3       0       2   4449.4620

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
x=df.drop(columns=['charges'])
y=df['charges']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7833463107364539

# %%
# apply on tips data
df=pd.read_csv('/content/tips - tips.csv')

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
df['sex']=lb.fit_transform(df['sex'])
df['smoker']=lb.fit_transform(df['smoker'])
df['day']=lb.fit_transform(df['day'])
df['time']=lb.fit_transform(df['time'])

# %%
df.head(3)
# Out:
#    total_bill   tip  sex  smoker  day  time  size
# 0       16.99  1.01    0       0    2     0     2
# 1       10.34  1.66    1       0    2     0     3
# 2       21.01  3.50    1       0    2     0     3

# %%
x=df.drop(columns=['total_bill'])
y=df['total_bill']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6334779105328128

# %%
## Apply on salary data

# Prediction of an Analyst (Project)

# %%
df=pd.read_csv('/content/Salary_Data - Salary_Data.csv')

# %%
df.head(3)
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731

# %%
import plotly.express as px

# %%
import plotly.graph_objects as go

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
figure=px.scatter(data_frame=df,
                  x='Salary',
                  y='YearsExperience',
                  size='YearsExperience',
                  trendline='ols')

# %%
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x=np.asanyarray(df[['YearsExperience']]) #asanyarray yeh array mein convert kar raha hai..
y=np.asanyarray(df[['Salary']])

# %%
x_train, x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
le=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
a=float(input("Enter the years of experience:"))
features=np.array([[a]])
print("Predicted Salary= ",lr.predict(features))
# Out:
# Enter the years of experience:8.3
# Predicted Salary=  [[103539.25019293]]
