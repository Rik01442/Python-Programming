# %% [markdown]
# <a href="https://colab.research.google.com/github/Rik01442/Python-Programming/blob/main/Data_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data Distribution
# df => x(input) + y(target)
# x(input) => x_train + x_test
# y(target) => y_train + y_test

# ML_Model(x_train, y_train)
# prediction(x_test) => y_pred
# Accuracy(y_test, y_pred)

# %%
# df = cgpa, resume_score, placed
# x = cgpa, resume_score(100)
# y = placed(100)
# x = x_train(80), x_test(20)
# y = y_train(80, y_test(20)

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/placement.csv')

# %%
df.head(5)
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.shape
# Out:
# (100, 3)

# %%
x = df.drop(columns=['placed']) ###Input data
y = df['placed'] ###Target data

# %%
print("DataFrame shape = ", df.shape)
print("x shape = ", x.shape)
print("y shape = ", y.shape)
# Out:
# DataFrame shape =  (100, 3)
# x shape =  (100, 2)
# y shape =  (100,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=30)

# %%
print("DataFrame shape =", df.shape)
print("x shape =", x.shape)
print("x_train shape =", x_train.shape)
print("x_test shape =", x_test.shape)

print("y shape =", y.shape)
print("y_train shape =", y_train.shape)
print("y_test shape =", y_test.shape)
# Out:
# DataFrame shape = (100, 3)
# x shape = (100, 2)
# x_train shape = (80, 2)
# x_test shape = (20, 2)
# y shape = (100,)
# y_train shape = (80,)
# y_test shape = (20,)

# %%
# df(100, 3) = x(100,2) + y(100,1)
# x(100,2) = x_train(80,2) + x_test(20,2)
# y(100,1) = y_train(80,1) + y_test(20,1)

# %%
df = pd.read_csv('/content/covid_toy.csv')

# %%
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
df['has_covid'].value_counts()
# Out:
# has_covid
# No     55
# Yes    45
# Name: count, dtype: int64

# %%
df['gender'] = df['gender'].map({'Male':0, 'Female':1})

# %%
df['cough'] = df['cough'].map({'Mild':0, 'Strong':1})

# %%
df['city'] = df['city'].map({'Kolkata':0,'Bangalore':1, 'Delhi':2, 'Mumbai':3})

# %%
df['has_covid'] = df['has_covid'].map({'No':0, 'Yes':1})

# %%
df.head(3)
# Out:
#    age  gender  fever cough  city  has_covid
# 0   60       0  103.0  Mild     0          0
# 1   27       0  100.0  Mild     2          1
# 2   42       0  101.0  Mild     2          0

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer(strategy = "mean")

# %%
df['fever'] = si.fit_transform(df[['fever']]) ###fit means learn parameter and transform means

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64
