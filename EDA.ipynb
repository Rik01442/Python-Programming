# %%
# EDA - Exploratory Data Analysis - Data visualization

# A critical process in data science that involves examining and visualizing 
# data to understand its main characteristics, identify patterns, and uncover hidden relationships.
