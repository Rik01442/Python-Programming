# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\vijay\\OneDrive\\Desktop\\Programming\\Datasets\\covid_toy.csv')
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.tail()
# Out:
#     age  gender  fever   cough       city has_covid
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes

# %%
# Random index dataset
df.sample()
# Out:
#     age  gender  fever cough   city has_covid
# 38   49  Female  101.0  Mild  Delhi       Yes

# %%
df1 = pd.read_csv('C:\\Users\\vijay\\OneDrive\\Desktop\\Programming\\Datasets\\placement.csv')
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.sample()
# Out:
#     cgpa  resume_score  placed
# 29  6.19           7.3       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df['age'][0]
# Out:
# 60

# %%
top_left_corner_df = df.iloc[:4,:3]
top_left_corner_df
# Out:
#    age  gender  fever
# 0   60    Male  103.0
# 1   27    Male  100.0
# 2   42    Male  101.0
# 3   31  Female   98.0

# %%
df1.loc[0:4, ['cgpa', 'placed']]
# Out:
#    cgpa  placed
# 0  8.14       1
# 1  6.17       0
# 2  8.27       1
# 3  6.88       1
# 4  7.52       1

# %%
p = df.dtypes
p
# Out:
# age            int64
# gender        object
# fever        float64
# cough         object
# city          object
# has_covid     object
# dtype: object

# %%
b = df1.empty
b
# Out:
# False

# %%
drop1 = df.dropna()
drop1
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [90 rows x 6 columns]

# %%
drop1.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
dfflipkart = pd.read_csv('C:\\Users\\vijay\\OneDrive\\Desktop\\Programming\\Datasets\\flipkart.csv')
dfflipkart
# Out:
#     Sr. No.                                           Models  Ratings  \
# 0         1  SAMSUNG Galaxy A35 5G (Awesome Iceblue, 128 GB)      4.3
# 1         2       SAMSUNG Galaxy F06 5G (Lit Violet, 128 GB)      4.2
# 2         3              vivo T4x 5G (Pronto Purple, 128 GB)      4.5
# 3         4  OnePlus Nord CE4 lite 5G (SUPER SILVER, 128 GB)      4.4
# 4         5  SAMSUNG Galaxy A35 5G (Awesome Iceblue, 256 GB)      4.3
# 5         6          SAMSUNG Galaxy S24 FE 5G (Blue, 128 GB)      4.4
# 6         7     Infinix Note 50s 5G+ (Titanium Grey, 128 GB)      4.6
# 7         8             POCO C75 5G (Enchanted Green, 64 GB)      4.3
# 8         9         MOTOROLA g35 5G (Midnight Black, 128 GB)      4.2
# 9        10      SAMSUNG Galaxy F06 5G (Bahama Blue, 128 GB)      4.2
# 10       11    SAMSUNG Galaxy A35 5G (Awesome Lilac, 256 GB)      4.3
# 11       12      SAMSUNG Galaxy S24 5G (Marble Gray, 128 GB)      4.5
# ...

# %%
dfflipkart.head()
# Out:
#    Sr. No.                                           Models  Ratings  \
# 0        1  SAMSUNG Galaxy A35 5G (Awesome Iceblue, 128 GB)      4.3
# 1        2       SAMSUNG Galaxy F06 5G (Lit Violet, 128 GB)      4.2
# 2        3              vivo T4x 5G (Pronto Purple, 128 GB)      4.5
# 3        4  OnePlus Nord CE4 lite 5G (SUPER SILVER, 128 GB)      4.4
# 4        5  SAMSUNG Galaxy A35 5G (Awesome Iceblue, 256 GB)      4.3
#
#        Rating No. Amount of Reviews  \
# 0   5,574 Ratings       416 Reviews
# 1   4,020 Ratings       310 Reviews
# 2  29,451 Ratings     1,858 Reviews
# 3  15,995 Ratings       787 Reviews
# 4   5,574 Ratings       416 Reviews
#
#                                                RAM  \
# 0     8 GB RAM | 128 GB ROM | Expandable Upto 1 TB
# 1  4 GB RAM | 128 GB ROM | Expandable Upto 1500 GB
# 2                            6 GB RAM | 128 GB ROM
# 3                            8 GB RAM | 128 GB ROM
# 4     8 GB RAM | 256 GB ROM | Expandable Upto 1 TB
#
# ...

# %%
df.tail()
# Out:
#     age  gender  fever   cough       city has_covid
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes

# %%
df.sample()
# Out:
#     age  gender  fever cough    city has_covid
# 46   19  Female  101.0  Mild  Mumbai        No

# %%
df2 = pd.read_csv('C:\\Users\\vijay\\OneDrive\\Desktop\\Programming\\Datasets\\placement.csv')
df2
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df2.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df2.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df2.sample()
# Out:
#    cgpa  resume_score  placed
# 4  7.52           7.3       1

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df2.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
loc1 = df2.iloc[0:4, 0:3]
loc1
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
iloc1 = df2.iloc[2:4, 1:3]
iloc1
# Out:
#    resume_score  placed
# 2          8.86       1
# 3          7.27       1

# %%
empty1 = df2.empty
empty1
# Out:
# False

# %%
d = df2.size
d
# Out:
# 300

# %%
a = df2.values
a
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
p = df2.sort_values(by = 'resume_score')
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
df2['cgpa'] = df2['cgpa'].astype(int)
df2
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
df2['resume_score'] = df2['resume_score'].astype(int)
df2
# Out:
#     cgpa  resume_score  placed
# 0      8             6       1
# 1      6             5       0
# 2      8             8       1
# 3      6             7       1
# 4      7             7       1
# ..   ...           ...     ...
# 95     6             6       0
# 96     8             7       1
# 97     6             7       0
# 98     8             5       1
# 99     6             6       0
#
# [100 rows x 3 columns]

# %%
df2['cgpa'] = df2['cgpa'].add(5)
df2['resume_score'] = df2['resume_score'].add(4)
df2['placed'] = df2['placed'].add(6)

# %%
df2
# Out:
#     cgpa  resume_score  placed
# 0     13            10       7
# 1     11             9       6
# 2     13            12       7
# 3     11            11       7
# 4     12            11       7
# ..   ...           ...     ...
# 95    11            10       6
# 96    13            11       7
# 97    11            11       6
# 98    13             9       7
# 99    11            10       6
#
# [100 rows x 3 columns]

# %%
s = df2.count()
s
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
m = df2.max()
m
# Out:
# cgpa            14
# resume_score    13
# placed           7
# dtype: int64

# %%
q = df2.min()
q
# Out:
# cgpa            10
# resume_score     8
# placed           6
# dtype: int64

# %%
r = df2.mean()
r
# Out:
# cgpa            11.47
# resume_score    10.47
# placed           6.50
# dtype: float64

# %%
d = df2.median()
d
# Out:
# cgpa            11.0
# resume_score    11.0
# placed           6.5
# dtype: float64

# %%
g = df2.filter(items = ['cgpa', 'resume_score'])
g
# Out:
#     cgpa  resume_score
# 0     13            10
# 1     11             9
# 2     13            12
# 3     11            11
# 4     12            11
# ..   ...           ...
# 95    11            10
# 96    13            11
# 97    11            11
# 98    13             9
# 99    11            10
#
# [100 rows x 2 columns]

# %%
df2[['cgpa', 'resume_score']]
# Out:
#     cgpa  resume_score
# 0     13            10
# 1     11             9
# 2     13            12
# 3     11            11
# 4     12            11
# ..   ...           ...
# 95    11            10
# 96    13            11
# 97    11            11
# 98    13             9
# 99    11            10
#
# [100 rows x 2 columns]

# %%
c = df2.filter(items = [5,6], axis = 0)
c
# Out:
#    cgpa  resume_score  placed
# 5    13            10       7
# 6    10            11       6

# %%
s = df2.to_dict()
s
# Out:
# {'cgpa': {0: 13,
#   1: 11,
#   2: 13,
#   3: 11,
#   4: 12,
#   5: 13,
#   6: 10,
#   7: 11,
#   8: 11,
#   9: 12,
#   10: 11,
#   11: 10,
#   12: 11,
#   13: 13,
#   14: 12,
#   15: 13,
#   16: 13,
#   17: 12,
#   18: 10,
#   19: 11,
#   20: 10,
#   21: 11,
#   22: 11,
#   23: 11,
#   24: 13,
#   25: 12,
#   26: 11,
#   27: 10,
#   28: 12,
#   29: 11,
#   30: 12,
#   31: 10,
#   32: 10,
#   33: 13,
#   34: 13,
#   35: 13,
#   36: 13,
#   37: 14,
#   38: 11,
#   39: 12,
#   40: 13,
#   41: 13,
#   42: 11,
#   43: 13,
#   44: 10,
#   45: 13,
#   46: 10,
#   47: 12,
#   48: 10,
#   49: 10,
#   50: 13,
#   51: 11,
#   52: 10,
#   53: 11,
#   54: 10,
#   55: 11,
#   56: 11,
#   57: 11,
#   58: 11,
#   59: 10,
#   60: 10,
#   61: 11,
#   62: 10,
#   63: 13,
#   64: 12,
#   65: 11,
#   66: 13,
#   67: 11,
#   68: 11,
#   69: 13,
#   70: 12,
#   71: 12,
#   72: 12,
#   73: 10,
#   74: 10,
#   75: 11,
#   76: 14,
#   77: 10,
#   78: 10,
#   79: 10,
#   80: 12,
#   81: 11,
#   82: 12,
# ...

# %%
q = df2.to_string()
q
# Out:
# '    cgpa  resume_score  placed\n0     13            10       7\n1     11             9       6\n2     13            12       7\n3     11            11       7\n4     12            11       7\n5     13            10       7\n6     10            11       6\n7     11            10       6\n8     11            10       6\n9     12            11       7\n10    11            10       6\n11    10            10       6\n12    11            11       6\n13    13             9       7\n14    12            10       7\n15    13             9       7\n16    13            11       7\n17    12            12       7\n18    10             9       6\n19    11            12       7\n20    10            12       6\n21    11            11       6\n22    11             9       6\n23    11            11       6\n24    13            10       7\n25    12             9       7\n26    11            10       6\n27    10            10       6\n28    12            11       7\n29    11            11       6\n30   
# ...

# %%
e = df2.to_csv()
e
# Out:
# ',cgpa,resume_score,placed\r\n0,13,10,7\r\n1,11,9,6\r\n2,13,12,7\r\n3,11,11,7\r\n4,12,11,7\r\n5,13,10,7\r\n6,10,11,6\r\n7,11,10,6\r\n8,11,10,6\r\n9,12,11,7\r\n10,11,10,6\r\n11,10,10,6\r\n12,11,11,6\r\n13,13,9,7\r\n14,12,10,7\r\n15,13,9,7\r\n16,13,11,7\r\n17,12,12,7\r\n18,10,9,6\r\n19,11,12,7\r\n20,10,12,6\r\n21,11,11,6\r\n22,11,9,6\r\n23,11,11,6\r\n24,13,10,7\r\n25,12,9,7\r\n26,11,10,6\r\n27,10,10,6\r\n28,12,11,7\r\n29,11,11,6\r\n30,12,11,7\r\n31,10,11,6\r\n32,10,11,6\r\n33,13,11,7\r\n34,13,11,7\r\n35,13,11,7\r\n36,13,11,7\r\n37,14,12,7\r\n38,11,12,6\r\n39,12,10,7\r\n40,13,9,7\r\n41,13,9,7\r\n42,11,10,7\r\n43,13,11,7\r\n44,10,9,6\r\n45,13,9,7\r\n46,10,9,6\r\n47,12,12,7\r\n48,10,10,6\r\n49,10,10,6\r\n50,13,10,7\r\n51,11,11,6\r\n52,10,11,6\r\n53,11,11,6\r\n54,10,11,6\r\n55,11,10,7\r\n56,11,10,6\r\n57,11,11,6\r\n58,11,11,6\r\n59,10,11,6\r\n60,10,10,6\r\n61,11,11,7\r\n62,10,12,6\r\n63,13,11,7\r\n64,12,12,7\r\n65,11,12,6\r\n66,13,12,7\r\n67,11,10,7\r\n68,11,11,6\r\n69,13,13,7\r\n70,12,11,
# ...

# %%
idx = df2.columns
idx
# Out:
# Index(['cgpa', 'resume_score', 'placed'], dtype='object')

# %%
label = df2.columns[0]
label
# Out:
# 'cgpa'

# %%
p = df2.columns.tolist()
p
# Out:
# ['cgpa', 'resume_score', 'placed']

# %%
p = df2.rename(columns = {'cgpa':'updated_cgpa', 'resume_score':'sememster_score'})
p
# Out:
#     updated_cgpa  sememster_score  placed
# 0             13               10       7
# 1             11                9       6
# 2             13               12       7
# 3             11               11       7
# 4             12               11       7
# ..           ...              ...     ...
# 95            11               10       6
# 96            13               11       7
# 97            11               11       6
# 98            13                9       7
# 99            11               10       6
#
# [100 rows x 3 columns]

# %%
df2['Cgpan'] = df2['cgpa'].astype(int)
df2
# Out:
#     cgpa  resume_score  placed  Cgpan
# 0     13            10       7     13
# 1     11             9       6     11
# 2     13            12       7     13
# 3     11            11       7     11
# 4     12            11       7     12
# ..   ...           ...     ...    ...
# 95    11            10       6     11
# 96    13            11       7     13
# 97    11            11       6     11
# 98    13             9       7     13
# 99    11            10       6     11
#
# [100 rows x 4 columns]

# %%
a = df2.drop = ['Cgpan', 'placed']
# Out:
# ['Cgpan', 'placed']

# %%
df2['new'] = df2['cgpa'].where(df2['cgpa'] > 13, other = 0)
df2.tail(7)
# Out:
#     cgpa  resume_score  placed  Cgpan  new
# 93    14            11       7     14   14
# 94    13             8       7     13    0
# 95    11            10       6     11    0
# 96    13            11       7     13    0
# 97    11            11       6     11    0
# 98    13             9       7     13    0
# 99    11            10       6     11    0

# %%
# notes for df merging, concatenation

# dataframe merging

df1 = pd.DataFrame(
    {
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    },
    index=[0, 1, 2, 3],
)


df2 = pd.DataFrame(
    {
        "A": ["A4", "A5", "A6", "A7"],
        "B": ["B4", "B5", "B6", "B7"],
        "C": ["C4", "C5", "C6", "C7"],
        "D": ["D4", "D5", "D6", "D7"],
    },
    index=[4, 5, 6, 7],
)


df3 = pd.DataFrame(
    {
        "A": ["A8", "A9", "A10", "A11"],
        "B": ["B8", "B9", "B10", "B11"],
        "C": ["C8", "C9", "C10", "C11"],
        "D": ["D8", "D9", "D10", "D11"],
    },
    index=[8, 9, 10, 11],
)


frames = [df1, df2, df3]

result = pd.concat(frames)
result
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
data1 = {
    "name": ["Sally", "Mary", "John"],
    "age": [50, 40,30]
}

data2 = {
    "name": ["Sally", "Peter", "Micky"],
    "age": [77, 44, 22]
}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

new_df = df1.merge(df2, how = 'right')

# %%
new_df
# Out:
#     name  age
# 0  Sally   77
# 1  Peter   44
# 2  Micky   22

# %%
# Define a dictionary containing employee data
data1 = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
         'Age': [27, 24, 22, 32],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Msc', 'MA', 'MCA', 'Phd']}

# Define a dictionary containing employee data
data2 = {'Name': ['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh'],
         'Age': [17, 14, 12, 52],
         'Address': ['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
         'Qualification': ['Btech', 'B.A.','Bcom','B.hons']}

# %%
df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# %%
new_dt = pd.concat([df1, df2])

# %%
df = pd.merge(df1, df2, on = 'Address', how = 'inner')
df
# Out:
#    Name_x  Age_x    Address Qualification_x  Name_y  Age_y Qualification_y
# 0     Jai     27     Nagpur             Msc    Abhi     17           Btech
# 1  Princi     24     Kanpur              MA  Ayushi     14            B.A.
# 2  Gaurav     22  Allahabad             MCA  Dhiraj     12            Bcom
# 3    Anuj     32    Kannuaj             Phd  Hitesh     52          B.hons
